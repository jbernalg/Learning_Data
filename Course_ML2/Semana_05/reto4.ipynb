# %% [markdown]
# # __Reto 4: Transformacion de datos__

# %% [markdown]
# ## Objetivo

# %% [markdown]
# Aplicar las dos técnicas de escalado de datos vistas en la semana 5

# %% [markdown]
# ## Tarea 1

# %% [markdown]
# Cargar el dataset del titanic y eliminar las columnas 'Name' y 'Sex'.

# %%
# librerias
import pandas as pd
import numpy as np

# %%
# cargar datos
df = pd.read_csv('./titanic.csv')
df.sample(5)
# Out:
#      Survived  Pclass                                               Name  \
# 502         0       1          Mr. Victor de Satode Penasco y Castellana
# 405         1       2                      Master. William Rowe Richards
# 667         1       2  Mrs. Thomas William Solomon (Elizabeth Catheri...
# 514         0       3                                   Mr. Patrick Ryan
# 302         0       3                           Mr. Howard Hugh Williams
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard    Fare
# 502    male  18.0                        1                        0  108.90
# 405    male   3.0                        1                        1   18.75
# 667  female  40.0                        1                        1   39.00
# 514    male  30.0                        0                        0   24.15
# 302    male  28.0                        0                        0    8.05

# %%
# eliminar variables Name y Sex
df.drop(columns=['Name', 'Sex'], inplace=True)
df.sample(5)
# Out:
#      Survived  Pclass   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 84          1       3  33.0                        3                        0
# 121         0       2  32.5                        1                        0
# 154         0       1  51.0                        0                        1
# 756         0       3  23.0                        0                        0
# 395         0       2  46.0                        0                        0
#
#         Fare
# 84   15.8500
# 121  30.0708
# 154  61.3792
# 756  14.5000
# 395  26.0000
