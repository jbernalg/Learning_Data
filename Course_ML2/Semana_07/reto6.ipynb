# %% [markdown]
# # __Reto 6: Procesamiento de datasets__

# %% [markdown]
# ## Objetivo

# %% [markdown]
# Realizar operaciones de preprocesamiento sobre el dataset House Predicition Rent y alistarlo para entrenar un modelo de Machine Learning.

# %% [markdown]
# ## Tarea 1

# %% [markdown]
# Leer la documentacion del dataset y conocer cada una de las variables y lo que reresentan

# %% [markdown]
# # Reto 6 (10%)
# El estudiante deberá realizar las siguientes actividades con el dataset [House Prediction Rent (Clic aquí para descargarlo)](https://drive.google.com/uc?id=1zF8ZXbxSotjRpBhwuza0OhZB5MM21LfI&export=download):
#
#
# 1.   [Leer la documentación proporcionada por el autor](https://www.kaggle.com/datasets/iamsouravbanerjee/house-rent-prediction-dataset)
# 2.   Eliminar las columnas `Floor` y `Area Locality`
# 3.   Convertir el tipo de dato de la columna `Posted On` (De object a datetime).
# 4.   Aplicar codificación One Hot sobre las siguientes variables: `Area Type`, `City`, `Furnishing Status`, `Tenant Preferred`, `Point of Contact`
# 5. Aplicar `MinMaxScaler` a las variables: `BHK`, `Size`, y `Bathroom`
